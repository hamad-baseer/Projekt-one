# %%
import os
os.listdir("Course materials etc")
# Out:
# ['data.txt',
#  'fruits.txt',
#  'Learning+Path+Canva.png',
#  'smallgray (1).png',
#  'smallgray.png',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'temps_today.csv',
#  'Volcanoes.txt',
#  'world.json']

# %%
import pandas

# %%
df1=pandas.read_csv("Course materials etc/supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_excel("Course materials etc/supermarkets.xlsx",sheet_name=0)
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3=pandas.read_csv("Course materials etc/supermarkets-commas.txt")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4=pandas.read_csv("Course materials etc/supermarkets-semi-colons.txt",sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df5=pandas.read_json("Course materials etc/supermarkets.json")
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_csv("Course materials etc/data.txt", header=None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns=["ID", "Address", "City", "State", "Country", "Name", "Employees"]
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=df6.set_index("ID")
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("ID", inplace=True)
df6
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("Name", inplace=True, drop=False)
df6
# Out:
#                      Address           City             State Country  \
# Name
#  Madeira        3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df=pandas.read_csv("Course materials etc/supermarkets-semi-colons.txt",sep=";")
df
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.set_index("Address", inplace=True)
df
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df.loc["735 Dolores St":"332 Hill St","Country":"Employees"]
# Out:
#                Country          Name  Employees
# Address
# 735 Dolores St     USA   Bready Shop         15
# 332 Hill St        USA   Super River         25

# %%
df
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df.iloc[1:4,2:]
# Out:
#                Country          Name  Employees
# Address
# 735 Dolores St     USA   Bready Shop         15
# 332 Hill St        USA   Super River         25
# 3995 23rd St       USA    Ben's Shop         10

# %%
df
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df.drop("City",1)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_1088/2749543768.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop("City",1)
#                             State Country          Name  Employees
# Address
# 3666 21st St             CA 94114     USA       Madeira          8
# 735 Dolores St           CA 94119     USA   Bready Shop         15
# 332 Hill St      California 94114     USA   Super River         25
# 3995 23rd St             CA 94114     USA    Ben's Shop         10
# 1056 Sanchez St        California     USA       Sanchez         12
# 551 Alvarado St          CA 94114     USA    Richvalley         20

# %%
df.drop("3995 23rd St", 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_1088/1849483867.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop("3995 23rd St", 0)
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df.drop(df.index[0:3],0)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_1088/2615588909.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.index[0:3],0)
#                           City       State Country        Name  Employees
# Address
# 3995 23rd St     San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df.drop(df.columns[1:4],1)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_1088/3410374225.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns[1:4],1)
#                           City  Employees
# Address
# 3666 21st St     San Francisco          8
# 735 Dolores St   San Francisco         15
# 332 Hill St      San Francisco         25
# 3995 23rd St     San Francisco         10
# 1056 Sanchez St  San Francisco         12
# 551 Alvarado St  San Francisco         20

# %%
df.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df.columns
# Out:
# Index(['City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df["Continent"]=df["Country"]+", "+"North America"
df
# Out:
#                           City             State Country          Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       Madeira
# 735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St      San Francisco  California 94114     USA   Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees           Continent
# Address
# 3666 21st St             8  USA, North America
# 735 Dolores St          15  USA, North America
# 332 Hill St             25  USA, North America
# 3995 23rd St            10  USA, North America
# 1056 Sanchez St         12  USA, North America
# 551 Alvarado St         20  USA, North America

# %%
df.shape
# Out:
# (6, 6)

# %%
df_t=df.T
df_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# Name               Ben's Shop             Sanchez          Richvalley
# Employees                  10                  12                  20
# ...
